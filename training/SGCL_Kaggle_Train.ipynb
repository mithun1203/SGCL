# %% [markdown]
# # SG-CL Training on Kaggle
#
# Train SG-CL with offline ConceptNet KB (906K concepts), Phi-3-Mini, Tesla T4 GPU.

# %% [markdown]
# ## 1. Clone Repository

# %%
# !git clone https://github.com/mithun1203/SGCL.git
# %cd SGCL

# %% [markdown]
# ## 2. Install Dependencies

# %%
# !pip install -q torch transformers datasets peft accelerate bitsandbytes

# %% [markdown]
# ## 3. Download ConceptNet KB (~5 min)

# %%
# !python scripts/setup_kb_kaggle.py

# %% [markdown]
# ## 4. Verify KB

# %%
import json
kb = json.load(open('sid/knowledge_base.json'))
print(f'KB: {len(kb):,} concepts')

# %% [markdown]
# ## 5. Train SG-CL (~2-3 hours)

# %%
# !python training/kaggle_train_sgcl.py

# %% [markdown]
# ## 6. Check Results

# %%
# !ls -lh results/sgcl_phi3_mini/

# %% [markdown]
# ## 7. Archive Results

# %%
# !tar -czf sgcl_results.tar.gz results/
print('Download sgcl_results.tar.gz from Output tab')
